# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#memasukan data latih
datalatih = pd.read_excel(r"C:\Users\User\dataset2\datatesting2.xlsx")
datalatih.head(11)
#Prestasi Siswa = 1 == Ya 
#Prestasi Siswa = 2 == Tidak
#Prestasi Sekolah = 1 == Cukup
#Prestasi Sekolah = 2 == Baik
# Out:
#              Jurusan  Matematika  Bahasa_Inggris  Bahasa_Indonesia  \
# 0         Matematika          92              86                88
# 1         Matematika          90              86                85
# 2     Sastra Inggris          82              87                92
# 3         Matematika          93              82                85
# 4     Sastra Inggris          86              85                88
# 5         Matematika          91              83                84
# 6   Sastra Indonesia          88              80                90
# 7   Sastra Indonesia          84              82                88
# 8     Sastra Inggris          79              89                85
# 9     Sastra Inggris          83              88                81
# 10    Sastra Inggris          82              85                84
#
#     Prestasi Siswa  Prestasi Sekolah
# 0                1                 1
# 1                1                 2
# 2                2                 1
# ...

# %%
datalatih.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Jurusan           11 non-null     object
#  1   Matematika        11 non-null     int64
#  2   Bahasa_Inggris    11 non-null     int64
#  3   Bahasa_Indonesia  11 non-null     int64
#  4   Prestasi Siswa    11 non-null     int64
#  5   Prestasi Sekolah  11 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 660.0+ bytes

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(datalatih.Matematika, datalatih.Jurusan, s=10, c='b', marker="o", label='Nilai Matematika')
ax1.scatter(datalatih.Bahasa_Inggris, datalatih.Jurusan, s=10, c='r', marker="o", label='Nilai Bahasa Inggris')
ax1.scatter(datalatih.Bahasa_Indonesia, datalatih.Jurusan, s=10, c='g', marker="o", label='Nilai Bahasa Inggris')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=3)
plt.show()
